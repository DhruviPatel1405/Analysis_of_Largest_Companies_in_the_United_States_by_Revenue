# %%
import pandas as pd
import numpy as ny 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('LargestCompaniesInUSAbyReveneue.csv')

# %%
df.shape
# Out:
# (100, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    int64
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    object
#  4   Revenue growth          100 non-null    object
#  5   Employees               100 non-null    object
#  6   Headquarters            100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %%
df.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart       General merchandisers
# 1     2              Amazon  Retail and Cloud Computing
# 2     3               Apple        Electronics industry
# 3     4          CVS Health                  Healthcare
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees              Headquarters
# 0                572,754           2.4%  2,300,000     Bentonville, Arkansas
# 1                469,822          21.7%  1,608,000       Seattle, Washington
# 2                365,817          33.2%    154,000     Cupertino, California
# 3                292,111          32.0%    258,000  Woonsocket, Rhode Island
# 4                287,597          11.8%    350,000     Minnetonka, Minnesota

# %%
print(df.isnull().sum())
# Out:
# Rank                      0
# Name                      0
# Industry                  0
# Revenue (USD millions)    0
# Revenue growth            0
# Employees                 0
# Headquarters              0
# dtype: int64

# %%
df['Revenue growth'] = df['Revenue growth'].str.rstrip('%').astype(float)

# %%
df['Revenue (USD millions)'] = df['Revenue (USD millions)'].str.replace(',', '').astype(int)

# %%
df.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart       General merchandisers
# 1     2              Amazon  Retail and Cloud Computing
# 2     3               Apple        Electronics industry
# 3     4          CVS Health                  Healthcare
# 4     5  UnitedHealth Group                  Healthcare
#
#    Revenue (USD millions)  Revenue growth  Employees              Headquarters
# 0                  572754             2.4  2,300,000     Bentonville, Arkansas
# 1                  469822            21.7  1,608,000       Seattle, Washington
# 2                  365817            33.2    154,000     Cupertino, California
# 3                  292111            32.0    258,000  Woonsocket, Rhode Island
# 4                  287597            11.8    350,000     Minnetonka, Minnesota

# %%
df['Employees'] = df['Employees'].str.replace(',', '').astype(int)

# %%
df.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart       General merchandisers
# 1     2              Amazon  Retail and Cloud Computing
# 2     3               Apple        Electronics industry
# 3     4          CVS Health                  Healthcare
# 4     5  UnitedHealth Group                  Healthcare
#
#    Revenue (USD millions)  Revenue growth  Employees              Headquarters
# 0                  572754             2.4    2300000     Bentonville, Arkansas
# 1                  469822            21.7    1608000       Seattle, Washington
# 2                  365817            33.2     154000     Cupertino, California
# 3                  292111            32.0     258000  Woonsocket, Rhode Island
# 4                  287597            11.8     350000     Minnetonka, Minnesota

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Revenue (USD millions)', y='Name', data=df.head(10))
plt.title('Top 10 Companies by Revenue')
plt.xlabel('Revenue (USD millions)')
plt.ylabel('Company Name')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='Industry', data=df, order=df['Industry'].value_counts().index)
plt.title('Number of Companies in Each Industry')
plt.xlabel('Number of Companies')
plt.ylabel('Industry')
plt.show()

# %%
top_5_companies = df.head(5)
print(top_5_companies)
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart       General merchandisers
# 1     2              Amazon  Retail and Cloud Computing
# 2     3               Apple        Electronics industry
# 3     4          CVS Health                  Healthcare
# 4     5  UnitedHealth Group                  Healthcare
#
#    Revenue (USD millions)  Revenue growth  Employees              Headquarters
# 0                  572754             2.4    2300000     Bentonville, Arkansas
# 1                  469822            21.7    1608000       Seattle, Washington
# 2                  365817            33.2     154000     Cupertino, California
# 3                  292111            32.0     258000  Woonsocket, Rhode Island
# 4                  287597            11.8     350000     Minnetonka, Minnesota

# %%
print("Summary Statistics of Revenue Growth:")
print(df['Revenue growth'].describe())
# Out:
# Summary Statistics of Revenue Growth:
# count    100.000000
# mean      20.276000
# std       25.215444
# min        0.100000
# 25%        5.700000
# 50%       12.250000
# 75%       21.700000
# max      151.100000
# Name: Revenue growth, dtype: float64

# %%
industry_revenue = df.groupby('Industry')['Revenue (USD millions)'].sum().sort_values(ascending=False)
print(industry_revenue)
# Out:
# Industry
# Healthcare                         1065548
# Petroleum industry                 1010973
# Retail                              905624
# Technology                          894959
# Financials                          854099
# Pharmaceutical industry             691429
# Conglomerate                        583542
# General merchandisers               572754
# Retail and Cloud Computing          469822
# Electronics industry                365817
# Insurance                           329663
# Telecommunications                  301680
# Health Insurance                    257142
# Health                              238228
# Transportation                      181246
# Automotive industry                 136341
# Financial services                  127202
# Automotive                          127004
# Pharmaceuticals                      96032
# Financial                            91039
# Food industry                        85959
# Beverage                             79474
# Consumer products Manufacturing      76118
# Media                                67418
# Aerospace and Defense                67044
# Aerospace and defense                62286
# Chemical industry                    54968
# Automotive and Energy                53823
# Food Service                         51298
# Machinery                            50971
# Telecom Hardware Manufacturing       49818
# Food Processing                      47049
# Apparel                              44538
# Agriculture manufacturing            44024
# Medical devices                      43075
# Software                             40479
# Laboratory instruments               39211
# Beverages                            38655
# Airspace and defense                 38469
# Agriculture cooperative              38448
# Metals                               36484
# Name: Revenue (USD millions), dtype: int32
